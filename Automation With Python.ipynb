# %%
import numpy as np
import pandas as pd

# %% [markdown]
#  ## Read a CSV file from a URL with pandas

# %%
serieA = pd.read_csv('https://www.football-data.co.uk/new/BRA.csv')
serieA.rename(columns = {'FTHG': 'home_goals', 'FTAG': 'away_goals'},inplace = True)

# %%
serieA
# Out:
#      Country   League  Season        Date   Time           Home         Away  \
# 0     Brazil  Serie A    2012  19/05/2012  22:30      Palmeiras   Portuguesa
# 1     Brazil  Serie A    2012  19/05/2012  22:30   Sport Recife  Flamengo RJ
# 2     Brazil  Serie A    2012  20/05/2012  01:00    Figueirense      Nautico
# 3     Brazil  Serie A    2012  20/05/2012  20:00    Botafogo RJ    Sao Paulo
# 4     Brazil  Serie A    2012  20/05/2012  20:00    Corinthians   Fluminense
# ...      ...      ...     ...         ...    ...            ...          ...
# 4555  Brazil  Serie A    2023  07/12/2023  00:30     Fluminense       Gremio
# 4556  Brazil  Serie A    2023  07/12/2023  00:30  Internacional  Botafogo RJ
# 4557  Brazil  Serie A    2023  07/12/2023  00:30         Santos    Fortaleza
# 4558  Brazil  Serie A    2023  07/12/2023  00:30      Sao Paulo  Flamengo RJ
# 4559  Brazil  Serie A    2023  07/12/2023  00:30          Vasco   Bragantino
#
# ...
